# %%
import cv2, os, glob
import numpy as np
import matplotlib.pyplot as plt
from keras.layers import Conv2D, Input, Activation
from keras.models import Model
from keras.models import load_model
from keras.callbacks import ModelCheckpoint
from skimage.transform import pyramid_expand
from Subpixel import Subpixel
from DataGenerator import DataGenerator
# Out:
# Using TensorFlow backend.

# %%
base_path = 'celeba-dataset/processed'

x_train_list = sorted(glob.glob(os.path.join(base_path, 'x_train', '*.npy')))
x_val_list = sorted(glob.glob(os.path.join(base_path, 'x_val', '*.npy')))

print(len(x_train_list), len(x_val_list))
print(x_train_list[0])
# Out:
# 162770 19867
# celeba-dataset/processed\x_train\000001.npy

# %%
x1 = np.load(x_train_list[0])
x2 = np.load(x_val_list[0])

print(x1.shape, x2.shape)

plt.subplot(1, 2, 1)
plt.imshow(x1)
plt.subplot(1, 2, 2)
plt.imshow(x2)
# Out:
# (44, 44, 3) (44, 44, 3)

# %%
train_gen = DataGenerator(list_IDs=x_train_list, labels=None, batch_size=16, dim=(44,44), n_channels=3, n_classes=None, shuffle=True)

val_gen = DataGenerator(list_IDs=x_val_list, labels=None, batch_size=16, dim=(44,44), n_channels=3, n_classes=None, shuffle=False)

# %%
upscale_factor = 4

inputs = Input(shape=(44, 44, 3))

net = Conv2D(filters=64, kernel_size=5, strides=1, padding='same', activation='relu')(inputs)
net = Conv2D(filters=64, kernel_size=3, strides=1, padding='same', activation='relu')(net)
net = Conv2D(filters=32, kernel_size=3, strides=1, padding='same', activation='relu')(net)
net = Conv2D(filters=upscale_factor**2, kernel_size=3, strides=1, padding='same', activation='relu')(net)
net = Subpixel(filters=3, kernel_size=3, r=upscale_factor, padding='same')(net)
outputs = Activation('relu')(net)

model = Model(inputs=inputs, outputs=outputs)

model.compile(optimizer='adam', loss='mse')

model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 44, 44, 3)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 44, 44, 64)        4864
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 44, 44, 64)        36928
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 44, 44, 32)        18464
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 44, 44, 16)        4624
# _________________________________________________________________
# subpixel_1 (Subpixel)        (None, 176, 176, 3)       6960
# _________________________________________________________________
# activation_1 (Activation)    (None, 176, 176, 3)       0
# =================================================================
# Total params: 71,840
# Trainable params: 71,840
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit_generator(train_gen, validation_data=val_gen, epochs=5, verbose=1, callbacks=[
    ModelCheckpoint('models/model.h5', monitor='val_loss', verbose=1, save_best_only=True)
])
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W1031 11:05:37.304689 12788 deprecation_wrapper.py:119] From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
# Epoch 1/5
# 10173/10173 [==============================] - 2475s 243ms/step - loss: 0.0024 - val_loss: 0.0023
#
# Epoch 00001: val_loss improved from inf to 0.00233, saving model to models/model.h5
# Epoch 2/5
# 10173/10173 [==============================] - 2626s 258ms/step - loss: 0.0015 - val_loss: 0.0022
#
# Epoch 00002: val_loss improved from 0.00233 to 0.00221, saving model to models/model.h5
# Epoch 3/5
# 10173/10173 [==============================] - 2960s 291ms/step - loss: 0.0014 - val_loss: 0.0021
#
# Epoch 00003: val_loss improved from 0.00221 to 0.00211, saving model to models/model.h5
# Epoch 4/5
# 10173/10173 [==============================] - 2696s 265ms/step - loss: 0.0014 - val_loss: 0.0022
#
# Epoch 00004: val_loss did not improve from 0.00211
# Epoch 5/5
# 10173/10173 [==============================] - 3218s 316ms/step - loss: 0.0014 - val_loss: 0.0021
#
# Epoch 00005: val_loss did not improve from 0.00211

# %%
x_test_list = sorted(glob.glob(os.path.join(base_path, 'x_test', '*.npy')))
y_test_list = sorted(glob.glob(os.path.join(base_path, 'y_test', '*.npy')))

print(len(x_test_list), len(y_test_list))
print(x_test_list[0])
# Out:
# 19962 19962
# celeba-dataset/processed\x_test\182638.npy

# %%
model = load_model('models/model.h5', custom_objects={'Subpixel':Subpixel})

# %%
test_idx = 26

x1_test = np.load(x_test_list[test_idx])
x1_test_resized = pyramid_expand(x1_test, 4)
y1_test = np.load(y_test_list[test_idx])
y_pred = model.predict(x1_test.reshape((1, 44, 44, 3)))


x1_test = (x1_test * 255).astype(np.uint8)
x1_test_resized = (x1_test_resized * 255).astype(np.uint8)
y1_test = (y1_test * 255).astype(np.uint8)
y_pred = np.clip(y_pred.reshape((176, 176, 3)), 0, 1)


x1_test = cv2.cvtColor(x1_test, cv2.COLOR_BGR2RGB)
x1_test_resized = cv2.cvtColor(x1_test_resized, cv2.COLOR_BGR2RGB)
y1_test = cv2.cvtColor(y1_test, cv2.COLOR_BGR2RGB)
y_pred = cv2.cvtColor(y_pred, cv2.COLOR_BGR2RGB)
y_pred = (y_pred * 255).astype('uint8')

cv2.imwrite('test.jpg', y_pred)


plt.figure(figsize=(15, 10))
plt.subplot(1, 4, 1)
plt.title('input')
plt.imshow(x1_test)
plt.subplot(1, 4, 2)
plt.title('resized')
plt.imshow(x1_test_resized)
plt.subplot(1, 4, 3)
plt.title('output')
plt.imshow(y_pred)
plt.subplot(1, 4, 4)
plt.title('groundtruth')
plt.imshow(y1_test)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\skimage\transform\_warps.py:24: UserWarning: The default multichannel argument (None) is deprecated.  Please specify either True or False explicitly.  multichannel will default to False starting with release 0.16.
#   warn('The default multichannel argument (None) is deprecated.  Please '

# %%
x1_test_resized.shape

# %%
y_pred * 255

# %%
a =
